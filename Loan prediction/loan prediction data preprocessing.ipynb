# %%
import pandas as pd
import numpy as np
import matplotlib
# %matplotlib inline
import pandas_profiling as pp
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import LabelEncoder,OneHotEncoder

# %%
train =pd.read_csv("train_u6lujuX_CVtuZ9i.csv")

# %%
test =pd.read_csv("test_Y3wMUE5_7gLdaTN.csv")

# %%
sample_submit = pd.read_csv("Sample_Submission_ZAuTl8O_FK3zQHh.csv")

# %%
train.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
test.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# 2             5000               1800       208.0             360.0
# 3             2340               2546       100.0             360.0
# 4             3276                  0        78.0             360.0
#
#    Credit_History Property_Area
# 0             1.0         Urban
# 1             1.0         Urban
# 2             1.0         Urban
# ...

# %%
sample_submit.head()
# Out:
# Empty DataFrame
# Columns: [Loan_ID, Loan_Status]
# Index: []

# %%
train.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
test.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area'],
#       dtype='object')

# %%
train.columns.difference(test.columns)
# Out:
# Index(['Loan_Status'], dtype='object')

# %%
print("train size :",train.shape)
print("test size :",test.shape)
# Out:
# train size : (614, 13)
# test size : (367, 12)

# %%
train["source"] = "train"
test["source"] = "test"

# %%
train.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status source
# 0             1.0         Urban           Y  train
# 1             1.0         Rural           N  train
# ...

# %%
test.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# 2             5000               1800       208.0             360.0
# 3             2340               2546       100.0             360.0
# 4             3276                  0        78.0             360.0
#
#    Credit_History Property_Area source
# 0             1.0         Urban   test
# 1             1.0         Urban   test
# ...

# %%
dataf = pd.concat([train,test],axis=0)

# %%
dataf.isnull().sum()
# Out:
# ApplicantIncome        0
# CoapplicantIncome      0
# Credit_History        79
# Dependents            25
# Education              0
# Gender                24
# LoanAmount            27
# Loan_Amount_Term      20
# Loan_ID                0
# Loan_Status          367
# Married                3
# Property_Area          0
# Self_Employed         55
# source                 0
# dtype: int64

# %%
dataf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 981 entries, 0 to 366
# Data columns (total 14 columns):
# ApplicantIncome      981 non-null int64
# CoapplicantIncome    981 non-null float64
# Credit_History       902 non-null float64
# Dependents           956 non-null object
# Education            981 non-null object
# Gender               957 non-null object
# LoanAmount           954 non-null float64
# Loan_Amount_Term     961 non-null float64
# Loan_ID              981 non-null object
# Loan_Status          614 non-null object
# Married              978 non-null object
# Property_Area        981 non-null object
# Self_Employed        926 non-null object
# source               981 non-null object
# dtypes: float64(4), int64(1), object(9)
# memory usage: 115.0+ KB

# %%
dataf.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  Credit_History  LoanAmount  \
# count       981.000000         981.000000      902.000000  954.000000
# mean       5179.795107        1601.916330        0.835920  142.511530
# std        5695.104533        2718.772806        0.370553   77.421743
# min           0.000000           0.000000        0.000000    9.000000
# 25%        2875.000000           0.000000        1.000000  100.000000
# 50%        3800.000000        1110.000000        1.000000  126.000000
# 75%        5516.000000        2365.000000        1.000000  162.000000
# max       81000.000000       41667.000000        1.000000  700.000000
#
#        Loan_Amount_Term
# count        961.000000
# mean         342.201873
# std           65.100602
# min            6.000000
# 25%          360.000000
# 50%          360.000000
# 75%          360.000000
# max          480.000000

# %%
dataf.nunique()
# Out:
# ApplicantIncome      752
# CoapplicantIncome    437
# Credit_History         2
# Dependents             4
# Education              2
# Gender                 2
# LoanAmount           232
# Loan_Amount_Term      12
# Loan_ID              981
# Loan_Status            2
# Married                2
# Property_Area          3
# Self_Employed          2
# source                 2
# dtype: int64

# %%
dataf.shape
# Out:
# (981, 14)

# %%
dataf.isnull().sum()
# Out:
# ApplicantIncome        0
# CoapplicantIncome      0
# Credit_History        79
# Dependents            25
# Education              0
# Gender                24
# LoanAmount            27
# Loan_Amount_Term      20
# Loan_ID                0
# Loan_Status          367
# Married                3
# Property_Area          0
# Self_Employed         55
# source                 0
# dtype: int64

# %%
import pandas_profiling

# %%
pandas_profiling.ProfileReport(dataf)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...

# %%
dataf["CoapplicantIncome"].value_counts()
# Out:
# 0.0       429
# 2500.0      6
# 2083.0      5
# 2000.0      5
# 2333.0      5
# 1666.0      5
# 700.0       4
# 1800.0      4
# 1250.0      4
# 1750.0      3
# 2250.0      3
# 5625.0      3
# 3167.0      3
# 2925.0      3
# 2900.0      3
# 3750.0      3
# 1300.0      3
# 1625.0      3
# 2166.0      3
# 1917.0      3
# 1500.0      3
# 1560.0      3
# 1083.0      3
# 1459.0      3
# 3583.0      3
# 2400.0      3
# 2167.0      3
# 833.0       2
# 5000.0      2
# 1600.0      2
#          ...
# 7916.0      1
# 2988.0      1
# 2108.0      1
# 5105.0      1
# 7250.0      1
# 4614.0      1
# 2079.0      1
# 3369.0      1
# 2138.0      1
# 1380.0      1
# 2773.0      1
# 2367.0      1
# 828.0       1
# 187.0       1
# 2125.0      1
# 6667.0      1
# 1425.0      1
# 3541.0      1
# 7166.0      1
# 3033.0      1
# 1863.0      1
# 1779.0      1
# 3338.0      1
# 5500.0      1
# 7101.0      1
# 1131.0      1
# 4700.0      1
# 2374.0      1
# 5302.0      1
# 3422.0      1
# ...

# %%
    
dataf["Education"].value_counts()
# Out:
# Graduate        763
# Not Graduate    218
# Name: Education, dtype: int64

# %%
#dataf["CoapplicantIncome"] = dataf.groupby("Education").CoapplicantIncome.transform(lambda x : x.fillna(x.mean))

# %%
dataf.columns
# Out:
# Index(['ApplicantIncome', 'CoapplicantIncome', 'Credit_History', 'Dependents',
#        'Education', 'Gender', 'LoanAmount', 'Loan_Amount_Term', 'Loan_ID',
#        'Loan_Status', 'Married', 'Property_Area', 'Self_Employed', 'source'],
#       dtype='object')

# %%
dataf['Credit_History']=dataf['Credit_History'].fillna(dataf['Credit_History'].mode()[0])

# %%
dataf['Credit_History'].value_counts()
# Out:
# 1.0    833
# 0.0    148
# Name: Credit_History, dtype: int64

# %%
 
dataf['Dependents'].value_counts()
# Out:
# 0     545
# 2     160
# 1     160
# 3+     91
# Name: Dependents, dtype: int64

# %%
dataf['Dependents']=dataf['Dependents'].fillna(dataf['Dependents'].mode()[0])

# %%
dataf["LoanAmount"] = dataf.groupby("Education").LoanAmount.transform(lambda x : x.fillna(x.mean()))

# %%
dataf['LoanAmount'].value_counts()
# Out:
# 120.000000    29
# 110.000000    27
# 100.000000    24
# 187.000000    21
# 150.000000    19
# 149.297043    19
# 130.000000    18
# 125.000000    18
# 160.000000    17
# 90.000000     15
# 135.000000    14
# 113.000000    14
# 128.000000    14
# 108.000000    13
# 104.000000    12
# 95.000000     12
# 80.000000     12
# 70.000000     12
# 96.000000     12
# 200.000000    10
# 132.000000    10
# 115.000000    10
# 138.000000    10
# 116.000000    10
# 180.000000    10
# 185.000000    10
# 140.000000     9
# 158.000000     9
# 152.000000     9
# 131.000000     9
#               ..
# 650.000000     1
# 54.000000      1
# 42.000000      1
# 436.000000     1
# 349.000000     1
# 254.000000     1
# 73.000000      1
# 228.000000     1
# 256.000000     1
# 308.000000     1
# 68.000000      1
# 79.000000      1
# 178.000000     1
# 218.000000     1
# 62.000000      1
# 370.000000     1
# 53.000000      1
# 336.000000     1
# 167.000000     1
# 311.000000     1
# 286.000000     1
# ...

# %%
dataf['Loan_Amount_Term'].value_counts()
# Out:
# 360.0    823
# 180.0     66
# 480.0     23
# 300.0     20
# 240.0      8
# 84.0       7
# 120.0      4
# 36.0       3
# 60.0       3
# 12.0       2
# 350.0      1
# 6.0        1
# Name: Loan_Amount_Term, dtype: int64

# %%
dataf['Loan_Amount_Term'] = dataf['Loan_Amount_Term'].transform(lambda x : x.fillna(x.median()))

# %%
dataf.isnull().sum()
# Out:
# ApplicantIncome        0
# CoapplicantIncome      0
# Credit_History         0
# Dependents             0
# Education              0
# Gender                24
# LoanAmount             0
# Loan_Amount_Term       0
# Loan_ID                0
# Loan_Status          367
# Married                3
# Property_Area          0
# Self_Employed         55
# source                 0
# dtype: int64

# %%
dataf['Married']=dataf['Married'].fillna(dataf['Married'].mode()[0])

# %%
dataf['Gender']=dataf['Gender'].fillna(dataf['Gender'].mode()[0])

# %%
dataf['Self_Employed'].value_counts()
# Out:
# No     807
# Yes    119
# Name: Self_Employed, dtype: int64

# %%
dataf["Self_Employed"] = dataf.groupby("ApplicantIncome").Self_Employed.transform(lambda x : x.fillna(x.mode()))

# %%
dataf.isnull().sum()
# Out:
# ApplicantIncome        0
# CoapplicantIncome      0
# Credit_History         0
# Dependents             0
# Education              0
# Gender                 0
# LoanAmount             0
# Loan_Amount_Term       0
# Loan_ID                0
# Loan_Status          367
# Married                0
# Property_Area          0
# Self_Employed         55
# source                 0
# dtype: int64

# %%
import pandas_profiling
pandas_profiling.ProfileReport(dataf)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...

# %%
dataf.head()
# Out:
#    ApplicantIncome  CoapplicantIncome  Credit_History Dependents  \
# 0             5849                0.0             1.0          0
# 1             4583             1508.0             1.0          1
# 2             3000                0.0             1.0          0
# 3             2583             2358.0             1.0          0
# 4             6000                0.0             1.0          0
#
#       Education Gender  LoanAmount  Loan_Amount_Term   Loan_ID Loan_Status  \
# 0      Graduate   Male  149.297043             360.0  LP001002           Y
# 1      Graduate   Male  128.000000             360.0  LP001003           N
# 2      Graduate   Male   66.000000             360.0  LP001005           Y
# 3  Not Graduate   Male  120.000000             360.0  LP001006           Y
# 4      Graduate   Male  141.000000             360.0  LP001008           Y
#
#   Married Property_Area Self_Employed source
# 0      No         Urban            No  train
# ...

# %%
dataf['Self_Employed']=dataf['Self_Employed'].fillna(dataf['Self_Employed'].mode()[0])

# %%
dataf['Loan_Status'] = dataf['Loan_Status'].transform(lambda x : x.fillna('UNKNOWN'))

# %%
dataf.loc[dataf.CoapplicantIncome==0.000000,"CoapplicantIncome"]=np.nan

# %%
dataf.loc[dataf.Credit_History==0.000000,"Credit_History"]=np.nan

# %%
dataf['Credit_History']=dataf['Credit_History'].fillna(dataf['Credit_History'].mode()[0])

# %%
dataf["CoapplicantIncome"] = dataf.groupby("Education").CoapplicantIncome.transform(lambda x : x.fillna(x.mean()))

# %%
import pandas_profiling
pandas_profiling.ProfileReport(dataf)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...

# %%
data_column_category = dataf.select_dtypes(exclude=[np.number]).columns

# %%
data_column_category
# Out:
# Index(['Dependents', 'Education', 'Gender', 'Loan_ID', 'Loan_Status',
#        'Married', 'Property_Area', 'Self_Employed', 'source'],
#       dtype='object')

# %%
data_column_Integer = dataf.columns.difference(data_column_category)
data_column_Integer
# Out:
# Index(['ApplicantIncome', 'CoapplicantIncome', 'Credit_History', 'LoanAmount',
#        'Loan_Amount_Term'],
#       dtype='object')

# %%
dataf[data_column_category].nunique()
# Out:
# Dependents         4
# Education          2
# Gender             2
# Loan_ID          981
# Loan_Status        3
# Married            2
# Property_Area      3
# Self_Employed      2
# source             2
# dtype: int64

# %%
data_column_category= data_column_category.drop( ['Loan_ID','Loan_Status'])

# %%
dataf_one_hot=pd.get_dummies(dataf[data_column_category])

# %%
values=dataf['Loan_Status']
label_encoder=LabelEncoder()
integer_encoded_1=label_encoder.fit_transform(values)
#df_ln["Loan_Status"] = df_ln.Loan_Status.replace({'1':'3','2':'1'})
#print(integer_encoded_1

# %%
dataf=dataf.drop(["Loan_Status"],axis=1)
dataf["Loan_Status"] = integer_encoded_1
dataf.head()
dataf["Loan_Status"] = dataf.Loan_Status.replace({1:3,2:1})
dataf["Loan_Status"] = dataf.Loan_Status.replace({3:2})
dataf.head()
# Out:
#    ApplicantIncome  CoapplicantIncome  Credit_History Dependents  \
# 0             5849        3069.473619             1.0          0
# 1             4583        1508.000000             1.0          1
# 2             3000        3069.473619             1.0          0
# 3             2583        2358.000000             1.0          0
# 4             6000        3069.473619             1.0          0
#
#       Education Gender  LoanAmount  Loan_Amount_Term   Loan_ID Married  \
# 0      Graduate   Male  149.297043             360.0  LP001002      No
# 1      Graduate   Male  128.000000             360.0  LP001003     Yes
# 2      Graduate   Male   66.000000             360.0  LP001005     Yes
# 3  Not Graduate   Male  120.000000             360.0  LP001006     Yes
# 4      Graduate   Male  141.000000             360.0  LP001008      No
#
#   Property_Area Self_Employed source  Loan_Status
# 0         Urban            No  train            1
# ...

# %%
dataf_one_hot.head()
# Out:
#    Dependents_0  Dependents_1  Dependents_2  Dependents_3+  \
# 0             1             0             0              0
# 1             0             1             0              0
# 2             1             0             0              0
# 3             1             0             0              0
# 4             1             0             0              0
#
#    Education_Graduate  Education_Not Graduate  Gender_Female  Gender_Male  \
# 0                   1                       0              0            1
# 1                   1                       0              0            1
# 2                   1                       0              0            1
# 3                   0                       1              0            1
# 4                   1                       0              0            1
#
#    Married_No  Married_Yes  Property_Area_Rural  Property_Area_Semiurban  \
# 0           1            0                    0                        0
# ...

# %%
dataf=dataf.drop(['Gender', 'Married', 'Dependents', 'Education','Self_Employed', 'Property_Area', 
                       'Source'])

# %%
dataf.columns
# Out:
# Index(['ApplicantIncome', 'CoapplicantIncome', 'Credit_History', 'Dependents',
#        'Education', 'Gender', 'LoanAmount', 'Loan_Amount_Term', 'Loan_ID',
#        'Married', 'Property_Area', 'Self_Employed', 'source', 'Loan_Status'],
#       dtype='object')

# %%
data_model = pd.concat([dataf[["Loan_ID","Loan_Status"]],dataf_one_hot,dataf[data_column_Integer]],axis=1)

# %%
dataf.columns
# Out:
# Index(['ApplicantIncome', 'CoapplicantIncome', 'Credit_History', 'Dependents',
#        'Education', 'Gender', 'LoanAmount', 'Loan_Amount_Term', 'Loan_ID',
#        'Married', 'Property_Area', 'Self_Employed', 'source', 'Loan_Status'],
#       dtype='object')

# %%
data_model.head(5)
# Out:
#     Loan_ID  Loan_Status  Dependents_0  Dependents_1  Dependents_2  \
# 0  LP001002            1             1             0             0
# 1  LP001003            0             0             1             0
# 2  LP001005            1             1             0             0
# 3  LP001006            1             1             0             0
# 4  LP001008            1             1             0             0
#
#    Dependents_3+  Education_Graduate  Education_Not Graduate  Gender_Female  \
# 0              0                   1                       0              0
# 1              0                   1                       0              0
# 2              0                   1                       0              0
# 3              0                   0                       1              0
# 4              0                   1                       0              0
#
#    Gender_Male        ...         Property_Area_Urban  Self_Employed_No  \
# ...

# %%
data_model.shape
# Out:
# (981, 24)

# %%
train_modified = data_model.loc[data_model.source_train==1.0,:]

# %%
test_modified = data_model.loc[data_model.source_train==0.0,:]

# %%
test_modified.shape
# Out:
# (367, 24)

# %%
train_modified.shape
# Out:
# (614, 24)

# %%
test_modified.columns
# Out:
# Index(['Loan_ID', 'Loan_Status', 'Dependents_0', 'Dependents_1',
#        'Dependents_2', 'Dependents_3+', 'Education_Graduate',
#        'Education_Not Graduate', 'Gender_Female', 'Gender_Male', 'Married_No',
#        'Married_Yes', 'Property_Area_Rural', 'Property_Area_Semiurban',
#        'Property_Area_Urban', 'Self_Employed_No', 'Self_Employed_Yes',
#        'source_test', 'source_train', 'ApplicantIncome', 'CoapplicantIncome',
#        'Credit_History', 'LoanAmount', 'Loan_Amount_Term'],
#       dtype='object')

# %%
test_modified.columns
# Out:
# Index(['Loan_ID', 'Loan_Status', 'Dependents_0', 'Dependents_1',
#        'Dependents_2', 'Dependents_3+', 'Education_Graduate',
#        'Education_Not Graduate', 'Gender_Female', 'Gender_Male', 'Married_No',
#        'Married_Yes', 'Property_Area_Rural', 'Property_Area_Semiurban',
#        'Property_Area_Urban', 'Self_Employed_No', 'Self_Employed_Yes',
#        'source_test', 'source_train', 'ApplicantIncome', 'CoapplicantIncome',
#        'Credit_History', 'LoanAmount', 'Loan_Amount_Term'],
#       dtype='object')

# %%
del test_modified['source_train']

# %%
del test_modified['Loan_Status']

# %%
del test_modified['source_test']

# %%
train_modified.head()
# Out:
#     Loan_ID  Loan_Status  Dependents_0  Dependents_1  Dependents_2  \
# 0  LP001002            1             1             0             0
# 1  LP001003            0             0             1             0
# 2  LP001005            1             1             0             0
# 3  LP001006            1             1             0             0
# 4  LP001008            1             1             0             0
#
#    Dependents_3+  Education_Graduate  Education_Not Graduate  Gender_Female  \
# 0              0                   1                       0              0
# 1              0                   1                       0              0
# 2              0                   1                       0              0
# 3              0                   0                       1              0
# 4              0                   1                       0              0
#
#    Gender_Male        ...         Property_Area_Urban  Self_Employed_No  \
# ...

# %%
del train_modified['source_test']

# %%
del train_modified['source_train']

# %%
train_modified.columns
# Out:
# Index(['Loan_ID', 'Loan_Status', 'Dependents_0', 'Dependents_1',
#        'Dependents_2', 'Dependents_3+', 'Education_Graduate',
#        'Education_Not Graduate', 'Gender_Female', 'Gender_Male', 'Married_No',
#        'Married_Yes', 'Property_Area_Rural', 'Property_Area_Semiurban',
#        'Property_Area_Urban', 'Self_Employed_No', 'Self_Employed_Yes',
#        'ApplicantIncome', 'CoapplicantIncome', 'Credit_History', 'LoanAmount',
#        'Loan_Amount_Term'],
#       dtype='object')

# %%
train_modified.to_csv("train_ready_for_model_loan.csv",index=False)
test_modified.to_csv("test_ready_for_model_loan.csv",index=False)
